# %%
import pandas as pd
from googletrans import Translator

# %%
data= pd.read_csv(r'C:\Users\my pc\Downloads\onemg_detail.csv')

# %%
data.columns
# Out:
# Index(['medName', 'manufacturer', 'Marketer Address', 'prescription_req',
#        'selling_price', 'salts', 'Units in Pack', 'Pack Size',
#        'Unit of Measurement', 'pack form', 'in_stock', 'Introduction', 'uses',
#        'benefits', 'directions', 'How medicine works', 'If you forgot to take',
#        'Quick Tips', 'side_effects', 'How to cope with side effects',
#        'precautions', 'pageURL', 'strength_in_mg', 'overall_strength'],
#       dtype='object')

# %%
for d in data:
    for i in data[d]:
        trans = Translator()
        t = trans.translate(i,src ='en',dest = 'hi')
        print(t.text)
# Out:
# एक्नेसोल जेल
# एम्ब्रोडिल सिरप
# ऑगमेंटिन 625 डुओ टैबलेट
# एज़िथ्रल 500 टैबलेट
# अल्कसोल मौखिक समाधान
# Allegra 120mg गोली
# एस्कोरिल एलएस सिरप
# एसिलोक 150 टैबलेट
# एविल 25 टैबलेट
# Azee 500 टैबलेट
# Aciloc RD 20 Tablet
# आर्कोलेन 2% स्कैल्प सॉल्यूशन
# Atarax 25mg टैबलेट
# ऑल्टरडे कैप्सूल एस.आर.
# एनोवेट क्रीम
# एम्ब्रोडिल-एस सिरप
# Allegra-M Tablet
# एस्कोरिल डी प्लस सिरप शुगर फ्री
# अर्कामिन टैबलेट
# एक्ससर 90mg टैबलेट
# एंड्रोजन समाधान
# एकनेस्टार जेल
# Asthakind-DX सिरप शुगर फ्री
# Allegra 180mg गोली
# Amlokind-AT Tablet
# Ativan 2mg टैबलेट
# Atarax 10mg टैबलेट
# एप्टिमस्ट सिरप
# एलेक्स सिरप
# एकट 4 किट
# अल्प्रैक्स 0.25 टैबलेट
# ए-रिट 0.1% जेल
# एल्डक्टोन टैबलेट
# AF किट टैबलेट
# अज़ोरन टैबलेट
# ऑगमेंटिन डीडीएस सस्पेंशन
# अटोरवा 40 टैबलेट
# Amlokind 5 टैबलेट
# एबी फीललाइन कैप्सूल
# अस्थलीन 100mcg इन्हेलर
# अल्फू 10mg टैबलेट पीआर
# अल्प्रैक्स 0.5mg टैबलेट एसआर
# एमोक्साइक्लेव 625 टैबलेट
# एलेक्स जूनियर सिरप
# एसिट्रोम 2 टैबलेट
# अनाफोर्टन 25 मिलीग्राम / 300 मिलीग्राम टैबलेट
# ...
